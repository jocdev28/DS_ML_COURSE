# %%
import pandas

# %%
pandas.__version__
# Out:
# '2.3.3'

# %%
1
# Out:
# 1

# %%
1.3
# Out:
# 1.3

# %%
type(1)
# Out:
# int

# %%
type(10.7)
# Out:
# float

# %%
type("12")
# Out:
# str

# %%
1+1
# Out:
# 2

# %%
2*8
# Out:
# 16

# %%
9/3
# Out:
# 3.0

# %%
10-4
# Out:
# 6

# %%
2**2
# Out:
# 4

# %%
9%3
# Out:
# 0

# %%
9%2
# Out:
# 1

# %%
name = "Julie"

# %%
print(f"My name is {name}")
# Out:
# My name is Julie
