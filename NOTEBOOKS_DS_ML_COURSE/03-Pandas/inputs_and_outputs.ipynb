# %%
import pandas as pd

# %% [markdown]
# #### CSV Files

# %%
# Find out what directory you're currently working in
# %pwd
# Out:
# 'C:\\Users\\inioluwa.daniel\\Documents\\DS_ML_COURSE\\NOTEBOOKS_DS_ML_COURSE\\03-Pandas'

# %%
# Check out the list of documents in that directory
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 587D-E488
#
#  Directory of C:\Users\inioluwa.daniel\Documents\DS_ML_COURSE\NOTEBOOKS_DS_ML_COURSE\03-Pandas
#
# 03/06/2026  15:42    <DIR>          .
# 18/03/2026  09:56    <DIR>          ..
# 03/06/2026  15:36    <DIR>          .ipynb_checkpoints
# 17/02/2026  13:52    <DIR>          __pycache__
# 17/02/2026  13:52           565,390 00-Series.ipynb
# 17/03/2026  15:45           209,646 01-DataFrames.ipynb
# 17/02/2026  13:52           194,591 02-Conditional-Filtering.ipynb
# 27/04/2026  09:57           197,230 03-Useful-Methods.ipynb
# 14/05/2026  13:32            64,240 04-Missing-Data.ipynb
# 17/02/2026  13:52           219,627 05-Groupby-Operations-and-MultiIndex.ipynb
# 03/06/2026  12:02            63,031 06-Combining-DataFrames.ipynb
# 03/06/2026  13:39            33,193 07-Text-Methods.ipynb
# 03/06/2026  13:42            94,237 08-Time-Methods.ipynb
# 03/06/2026  15:37            65,299 09-Inputs-and-Outputs.ipynb
# ...

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# Make some changes to the csv
df = pd.read_csv('example.csv', index_col=0)

# %% [markdown]
# df

# %%
# Save the dataframe. We can either input a name or a file path to save the file
df.to_csv('newfile.csv', index=True)

# %%
new = pd.read_csv('newfile.csv')

# %%
new
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %% [markdown]
# #### HTML Tables

# %%
# We'll get the table data from a website
url = "https://en.wikipedia.org/wiki/World_population"

# %%
tables = pd.read_html('sample_table.html')

# %%
len(tables)
# Out:
# 1

# %%
tables[0]
# Out:
#           Country   200  2015  2030 Est.
# 0        China[B]  1270  1376       1416
# 1           India  1053  1311       1528
# 2   United States   283   322        356
# 3       Indonesia   212   258        295
# 4        Pakistan   136   208        245
# 5          Brazil   176   206        228
# 6         Nigeria   123   182        263
# 7      Bangladesh   131   161        186
# 8          Russia   146   146        149
# 9          Mexico   103   127        148
# 10    World total  6127  7349       8501

# %% [markdown]
# #### Excel

# %%
df = pd.read_excel('my_excel_file.xlsx', sheet_name='First_Sheet')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# Running a loop through all the sheet names in the case where we do not know the names of the sheets (with larger workbooks)
work_book = pd.ExcelFile('my_excel_file.xlsx')

# %%
work_book.sheet_names
# Out:
# ['First_Sheet']

# %%
excel_sheet_dict = pd.read_excel('my_excel_file.xlsx', sheet_name=None)
